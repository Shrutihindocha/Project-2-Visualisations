# %%
from sqlalchemy import create_engine
import pandas as pd

# Path to sqlite
database_path = "combined_data.sqlite"

# Create an engine that can talk to the database
engine = create_engine(f"sqlite:///{database_path}")
conn = engine.connect()

# %%
## SQLAlchemy - checking if SQLite has been created correctly

data = pd.read_sql("SELECT * FROM combined_data", conn)
data
# Out:
#          index Reported Date Suburb - Incident Postcode - Incident  \
# 0            0     1/07/2014          ADELAIDE                5000
# 1            1     1/07/2014          ADELAIDE                5000
# 2            2     1/07/2014          ADELAIDE                5000
# 3            3     1/07/2014          ADELAIDE                5000
# 4            4     1/07/2014          ADELAIDE                5000
# ...        ...           ...               ...                 ...
# 645686  645686    30/06/2020        WEST LAKES                5021
# 645687  645687    30/06/2020    WHYALLA NORRIE                5608
# 645688  645688    30/06/2020   WOODVILLE NORTH                5012
# 645689  645689    30/06/2020              None                None
# 645690  645690    30/06/2020              None                None
#
#         Offence Level 1 Description           Offence Level 2 Description  \
# 0         OFFENCES AGAINST PROPERTY  FRAUD DECEPTION AND RELATED OFFENCES
# ...
